# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("/home/onix/Documents/data/manual/2023_10/10/119MHz_matched.csv", delimiter=",", skiprows=1).T

# %%
fig, ax = plt.subplots()
ax.plot(data[0] / 1e6, data[1])
ax1 = ax.twinx()
unwrapped_angles = data[2].copy()
for kk in range(len(unwrapped_angles)):
    if unwrapped_angles[kk] < unwrapped_angles[kk + 1] - 100:
        unwrapped_angles[kk + 1:] -= 360
        break
ax1.plot(data[0] / 1e6, unwrapped_angles, color="C1")
ax1.set_ylabel("Phase (deg)")
ax.set_xlabel("Frequency (MHz)")
ax.set_ylabel("Reflection coeffcient (dB)")
plt.show()

# %%
freqs = [134, 133, 132, 131, 130, 129, 128, 127, 126, 124, 123, 122, 121, 120, 119, 118, 117, 116, 115, 114]
reflect_mVrms = [292, 275, 278, 241, 106, 48, 155, 222, 245, 330, 345, 335, 300, 154, 45, 220, 345, 400, 414, 396]
pickup_mVrms = [150, 191, 307, 486, 490, 437, 414, 315, 212, 187, 187, 195, 240, 230, 210, 202, 173, 143, 119, 106]

# freqs = [114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 134]
# reflect_mVrms = [661, 832, 950, 1020, 1010, 927, 802, 630, 344, 170, 430, 650, 710, 725, 705, 657, 580, 410, 85, 313]
# pickup_mVrms = [61, 57, 56, 56, 59, 63, 71, 86, 106, 117, 108, 102, 118, 145, 177, 205, 220, 230, 200, 150]

#freqs = [110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 126, 127, 128, 129, 130]
#reflect_mVrms = [808, 850, 870, 880, 920, 830, 606, 420, 230, 200, 380, 610, 720, 660, 610, 670, 600, 650, 700, 675]
#pickup_mVrms = [75, 80, 85, 96, 125, 147, 144, 157, 187, 185, 190, 225, 240, 190, 160, 140, 150, 200, 290, 313]

freqs = np.array(freqs)
reflect_mVrms = np.array(reflect_mVrms)
pickup_mVrms = np.array(pickup_mVrms)

# %%
fig, ax = plt.subplots()
ax1 = ax.twinx()
ax.plot(freqs, reflect_mVrms, label="reflect")
ax1.plot(freqs, pickup_mVrms, color="C1", label="pickup")
ax.set_xlabel("Frequency (MHz)")
ax.set_ylabel("Reflection rms voltage (mV)")
ax1.set_ylabel("Pickup coil rms voltage (mV)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax1 = ax.twinx()
ax.plot(freqs, reflect_mVrms, label="reflect")
ax1.plot(freqs, pickup_mVrms, color="C1", label="pickup")
ax.set_xlabel("Frequency (MHz)")
ax.set_ylabel("Reflection rms voltage (mV)")
ax1.set_ylabel("Pickup coil rms voltage (mV)")
plt.legend()
plt.tight_layout()
plt.show()
