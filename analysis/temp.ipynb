# %%
import matplotlib.pyplot as plt
import numpy as np
from onix.data_tools import get_experiment_data
from uncertainties import unumpy
from onix.analysis.shared.main import OpticalAnalysis, ScanAnalysis, TimeSeriesAnalysis
# %matplotlib widget

# from plotly.subplots import make_subplots
# from plotly.offline import init_notebook_mode, iplo
# import plotly.graph_objs as go


# init_notebook_mode(connected=True) 

# TODO: browser/parser for data numbers.
# Out:
# /home/icarus/Documents/code/onix/analysis/shared/main.py:480: SyntaxWarning: invalid escape sequence '\P'
#   ax[i, 0].scatter(ts, fs, label=f"$\Pi$ = {Pi}", color=colors_12[j])
# /home/icarus/Documents/code/onix/analysis/shared/main.py:485: SyntaxWarning: invalid escape sequence '\S'
#   ax[sn, 0].scatter(ts, Zs, label=f"$\Sigma$ = {Sigma}", color=colors_34[i])
# /home/icarus/Documents/code/onix/analysis/shared/main.py:490: SyntaxWarning: invalid escape sequence '\S'
#   ax[sn+1, 0].scatter(ts, Ws, label=f"$\Sigma$ = {Sigma}", color=colors_34[i])
# /home/icarus/Documents/code/onix/analysis/shared/main.py:493: SyntaxWarning: invalid escape sequence '\P'
#   ax[i, 0].set_ylabel(f"$f(\Pi=\pm 1, \Sigma = {Sigma})$")
# /home/icarus/Documents/code/onix/analysis/shared/main.py:497: SyntaxWarning: invalid escape sequence '\p'
#   sigmas_str = "$\pm 1$"
# /home/icarus/Documents/code/onix/analysis/shared/main.py:500: SyntaxWarning: invalid escape sequence '\m'
#   ax[sn  , 0].set_ylabel("$\mathcal{Z}(\Sigma = $" + f"{sigmas_str}" +"$)$")
# /home/icarus/Documents/code/onix/analysis/shared/main.py:501: SyntaxWarning: invalid escape sequence '\m'
#   ax[sn+1, 0].set_ylabel("$\mathcal{W}(\Sigma = $" + f"{sigmas_str}" +"$)$")

# %%
# test = TimeSeriesAnalysis((6595967, 6599707-3600), 8) # from oct 2
test = TimeSeriesAnalysis((6599964, 6599964+500), 8) # from overnight end: 6644716


# test = TimeSeriesAnalysis((6651345, 6651345 + 160), 8) # same sigma
# Out:
# 100%|███████████████████████████████████████████| 62/62 [00:03<00:00, 20.53it/s]

# %%
test.subplots(None)
# Out:
# (<Figure size 1200x900 with 8 Axes>,
#  array([[<Axes: ylabel='$f(\\Pi=\\pm 1, \\Sigma = -1)$'>, <Axes: >],
#         [<Axes: ylabel='$f(\\Pi=\\pm 1, \\Sigma = 1)$'>, <Axes: >],
#         [<Axes: ylabel='$\\mathcal{Z}(\\Sigma = $$\\pm 1$$)$'>, <Axes: >],
#         [<Axes: xlabel='Time from start (s)', ylabel='$\\mathcal{W}(\\Sigma = $$\\pm 1$$)$'>,
#          <Axes: >]], dtype=object))
