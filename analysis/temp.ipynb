# %%
import matplotlib.pyplot as plt
import numpy as np
from onix.data_tools import get_experiment_data
from uncertainties import unumpy
from onix.analysis.shared.fitter import get_fitter, two_peak_gaussian
from onix.analysis.shared.main import opticalAnalysis, frequencyAnalysis
# %matplotlib widget

from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go

init_notebook_mode(connected=True) 

# TODO: browser/parser for data numbers.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = opticalAnalysis(6590805)

fig, ax = plt.subplots()
data.plot_optical_spectrum_data(ax)
data.plot_optical_spectrum_params(ax)
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data_numbers = (6064094+8*5, 6064101+8*5)
data_package_size = 1

data = frequencyAnalysis(data_numbers, data_package_size)

fig, ax = plt.subplots(figsize=(12, 8))
data.plot_sweep_data(ax, "phase_diffs")
data.plot_sweep_params(ax, "phase_diffs")
plt.show()
# Out:
#   0%|                                                                                                                                                                                     | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 data_numbers = (6064094+8*5, 6064101+8*5)
#       2 data_package_size = 1
# ----> 4 data = frequencyAnalysis(data_numbers, data_package_size)
#       6 fig, ax = plt.subplots(figsize=(12, 8))
#       7 data.plot_sweep_data(ax, "phase_diffs")
#
# File ~\Documents\code\onix\analysis\shared\main.py:155, in frequencyAnalysis.__init__(self, data_numbers, data_packet_size)
#     152 # shave down data_numbers to acceptable range (0 to len-len%packet_size)
#     153 self._data_numbers = data_numbers[0:len(data_numbers) - len(data_numbers) % data_packet_size]
# --> 155 self._a1s, self._a2s, self._headers = self.get_fits()
#
# File ~\Documents\code\onix\analysis\shared\main.py:166, in frequencyAnalysis.get_fits(self)
#     163 headers = []
#     165 for data_number in tqdm(self._data_numbers):
# --> 166     optical_data = opticalAnalysis(data_number)
#     167     a1, a2 = optical_data.get_fit_peaks()
#     168     a1s.append(a1)
#
# File ~\Documents\code\onix\analysis\shared\main.py:35, in opticalAnalysis.__init__(self, data_number, normalized, optical_depth)
#      33 self._normalized = normalized
#      34 self._optical_depth = optical_depth
# ---> 35 self._data, self._headers = get_experiment_data(self._data_number)
#      36 self._detunings = self._data["detunings_MHz"]
#      37 self._optical_depths = self.get_optical_spectrum()
#
# File ~\Documents\code\onix\data_tools\_data_handler.py:104, in get_experiment_data(data_number)
#     102 """Gets experiment data and headers."""
#     103 file_path = get_exist_experiment_path(data_number)
# --> 104 return _get_data(file_path)
#
# File ~\Documents\code\onix\data_tools\_data_handler.py:67, in _get_data(file_path)
#      64             return DummyClass
#      66 data = dict(np.load(file_path, allow_pickle=True))
# ---> 67 headers = SkipAttributeErrorUnpickler(io.BytesIO(data.pop("__headers__"))).load()
#      68 return (data, headers)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:1538, in _Unpickler.load_stack_global(self)
#    1536 if type(name) is not str or type(module) is not str:
#    1537     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1538 self.append(self.find_class(module, name))
#
# File ~\Documents\code\onix\data_tools\_data_handler.py:61, in _get_data.<locals>.SkipAttributeErrorUnpickler.find_class(self, _SkipAttributeErrorUnpickler__module_name, _SkipAttributeErrorUnpickler__global_name)
#      59 def find_class(self, __module_name: str, __global_name: str) -> Any:
#      60     try:
# ---> 61         return super().find_class(__module_name, __global_name)
#      62     except AttributeError:
#      63         print(f"Cannot find class {__global_name} in {__module_name}. Skipping.")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:1580, in _Unpickler.find_class(self, module, name)
#    1578     elif module in _compat_pickle.IMPORT_MAPPING:
#    1579         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1580 __import__(module, level=0)
#    1581 if self.proto >= 4:
#    1582     return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'onix.sequences.lf_quick_state_prep_axion'

# %%
data_numbers = (6270023, 6270350)
data_package_size = 8

data = frequencyAnalysis(data_numbers, data_package_size)

fig, ax = plt.subplots(figsize=(12, 8))
data.plot_time_series(ax)
data.plot_time_series_params(ax)
plt.show()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 328/328 [00:08<00:00, 39.02it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from onix.data_tools import get_processed_data, save_processed_data
import pandas as pd

# %%
scan = ["rf", "rabi", "detuning"]
thedict = data._headers["params"]
for step in scan: 
    thedict = thedict[step]
print(thedict)
# Out:
# -279.66101694915255 kilohertz

# %%
data = frequencyAnalysis((6591103, 6591160))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 56/56 [00:01<00:00, 32.36it/s]

# %%
data.get_list_from_header(["rf", "rabi", "detuning"])
# Out:
# <Quantity([-300.         -289.83050847 -279.66101695 -269.49152542 -259.3220339
#  -249.15254237 -238.98305085 -228.81355932 -218.6440678  -208.47457627
#  -198.30508475 -188.13559322 -177.96610169 -167.79661017 -157.62711864
#  -147.45762712 -137.28813559 -127.11864407 -116.94915254 -106.77966102
#   -96.61016949  -86.44067797  -76.27118644  -66.10169492  -55.93220339
#   -45.76271186  -35.59322034  -25.42372881  -15.25423729   -5.08474576
#     5.08474576   15.25423729   25.42372881   35.59322034   45.76271186
#    55.93220339   66.10169492   76.27118644   86.44067797   96.61016949
#   106.77966102  116.94915254  127.11864407  137.28813559  147.45762712
#   157.62711864  167.79661017  177.96610169  188.13559322  198.30508475
#   208.47457627  218.6440678   228.81355932  238.98305085  249.15254237
#   259.3220339 ], 'kilohertz')>

# %%
fig, ax = plt.subplots()
data.plot_sweep_data(ax, ["rf", "rabi", "detuning"])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test = data.get_list_from_header(["rf", "rabi", "detuning"])

# %%
type(test)
# Out:
# pint.Quantity
