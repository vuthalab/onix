# %%
import matplotlib.pyplot as plt
import numpy as np
from onix.data_tools import get_experiment_data
from uncertainties import unumpy
from onix.analysis.shared.analyzer import OpticalAnalysis, ScanAnalysis, TimeSeriesAnalysis
# %matplotlib widget

# from plotly.subplots import make_subplots
# from plotly.offline import init_notebook_mode, iplo
# import plotly.graph_objs as go


# init_notebook_mode(connected=True) 

# TODO: browser/parser for data numbers.
# Out:
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:523: SyntaxWarning: invalid escape sequence '\P'
#   ax[i, 0].scatter(ts, fs, label=f"$\Pi$ = {Pi}", color=colors_12[j])
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:528: SyntaxWarning: invalid escape sequence '\S'
#   ax[sn, 0].scatter(ts, Zs, label=f"$\Sigma$ = {Sigma}", color=colors_34[i])
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:533: SyntaxWarning: invalid escape sequence '\S'
#   ax[sn+1, 0].scatter(ts, Ws, label=f"$\Sigma$ = {Sigma}", color=colors_34[i])
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:536: SyntaxWarning: invalid escape sequence '\P'
#   ax[i, 0].set_ylabel(f"$f(\Pi=\pm 1, \Sigma = {Sigma})$")
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:540: SyntaxWarning: invalid escape sequence '\p'
#   sigmas_str = "$\pm 1$"
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:543: SyntaxWarning: invalid escape sequence '\m'
#   ax[sn  , 0].set_ylabel("$\mathcal{Z}(\Sigma = $" + f"{sigmas_str}" +"$)$")
# /home/icarus/Documents/code/onix/analysis/shared/analyzer.py:544: SyntaxWarning: invalid escape sequence '\m'
#   ax[sn+1, 0].set_ylabel("$\mathcal{W}(\Sigma = $" + f"{sigmas_str}" +"$)$")

# %%
# test = TimeSeriesAnalysis((6595967, 6599707-3600), 8) # from oct 2
test = TimeSeriesAnalysis((6658435, 6677689)) # from overnight end: 6644716


# test = TimeSeriesAnalysis((6651345, 6651345 + 160), 8) # same sigma
# Out:
# 100%|███████████████████████████████████████| 2406/2406 [01:44<00:00, 23.13it/s]

# %%
print(test._unique_scan)
# Out:
# {'chasm_amplitude': array([0.15]), 'chasm_duration': array([1]), 'chasm_repeats': array([100]), 'antihole_amplitude': array([0.15]), 'antihole_duration': array([1]), 'antihole_repeats': array([100]), 'center_frequency': array([139.85]), 'Sigma': array([-1,  1]), 'piov2_time': array([50]), 'wait_time': array([1000]), 'polarity': array([1]), 'detect_amplitude': array([17]), 'detect_repeats': array([512]), 'delay_time': array([0, 4])}

# %%
filter = test._data["delay_time"] == 0
# filter = None
test.subplots(filter)
plt.show()
test.print_info(filter)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# Date                       :  Thu Oct  3 21:09:15 2024
# Total experiment time      :  947.17 min
# First data number          :  6658435
# Last data number           :  6677682
# Packet size                :  8
#
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# f(Π = +1, Σ = -1)  = 134555.364(85) Hz
# f(Π = -1, Σ = -1)  = 134555.156(79) Hz
# f(Π = +1, Σ = 1)  = 143038.665(72) Hz
# f(Π = -1, Σ = 1)  = 143037.945(67) Hz
#
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# Z(Σ = -1) = 67277.630(35) Hz
# W(Σ = -1) = 0.069(29) Hz
# Z(Σ = 1) = 71519.153(29) Hz
# W(Σ = 1) = 0.240(25) Hz
#
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# Z = 69398(61) Hz
# W = 0.155(19) Hz
# S = 76.6 mHz rt-hr
#
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
filter = test._data["polarity"] > 0
